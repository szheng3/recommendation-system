# %% [markdown]
# # Self-Attentive Sequential Recommender (SASRec) + Supervised Advantage Actor-Critic (SA2C) Recommender on Retail Rocket Data
# In this notebook, we train an SASRec-SA2C model to recommend a list of items to users in the dataset. We are using Retail Rocket data to train this model.

# %% [markdown]
# 1. Clone the git repository containing all the source code

# %%
# !git clone https://github.com/architkaila/recommenders_aipi590.git
# Out:
# Cloning into 'recommenders_aipi590'...
# remote: Enumerating objects: 155, done.
# remote: Counting objects: 100% (155/155), done.
# remote: Compressing objects: 100% (95/95), done.
# remote: Total 155 (delta 80), reused 124 (delta 52), pack-reused 0
# Receiving objects: 100% (155/155), 63.51 KiB | 12.70 MiB/s, done.
# Resolving deltas: 100% (80/80), done.

# %% [markdown]
# 2. Install required libraries

# %%
# !pip install trfl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting trfl
#   Downloading trfl-1.2.0-py3-none-any.whl (104 kB)
#      |████████████████████████████████| 104 kB 19.4 MB/s
# Requirement already satisfied: wrapt in /usr/local/lib/python3.8/dist-packages (from trfl) (1.14.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from trfl) (1.21.6)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.8/dist-packages (from trfl) (1.3.0)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from trfl) (1.15.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.8/dist-packages (from trfl) (0.1.7)
# Installing collected packages: trfl
# Successfully installed trfl-1.2.0

# %% [markdown]
# 3. Download Retail Rocket events log from AWS S3 bucket to local

# %%
# !wget https://aipi590.s3.amazonaws.com/events.csv -P "/content/recommenders_aipi590/DRL_Recommenders/Dataset_1_Retail_Rocket/RR_data/"
# Out:
# --2022-12-13 14:53:48--  https://aipi590.s3.amazonaws.com/events.csv
# Resolving aipi590.s3.amazonaws.com (aipi590.s3.amazonaws.com)... 52.216.170.11, 52.216.113.163, 54.231.232.57, ...
# Connecting to aipi590.s3.amazonaws.com (aipi590.s3.amazonaws.com)|52.216.170.11|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 94237913 (90M) [text/csv]
# Saving to: ‘/content/recommenders_aipi590/DRL_Recommenders/Dataset_1_Retail_Rocket/RR_data/events.csv’
#
# events.csv          100%[===================>]  89.87M  46.4MB/s    in 1.9s
#
# 2022-12-13 14:53:50 (46.4 MB/s) - ‘/content/recommenders_aipi590/DRL_Recommenders/Dataset_1_Retail_Rocket/RR_data/events.csv’ saved [94237913/94237913]

# %% [markdown]
# 4. Run script to pre-process data and generate replay buffer

# %%
# !python "/content/recommenders_aipi590/DRL_Recommenders/Dataset_1_Retail_Rocket/src/gen_replay_buffer.py" --data="/content/recommenders_aipi590/DRL_Recommenders/Dataset_1_Retail_Rocket/RR_data/"
# Out:
# Starting to pre-process data...
#
# Sorting and pickling data...
#
# Splitting data into train, validation, and test sets...
#
# Pickling train, validation, and test sets...
#
# Calculating item popularity and storing as dictionary...
#
# Generating replay buffer from train set...
#
# Pickling replay buffer...
#
# Pickling data statistics...
#
# Script completed successfully!

# %% [markdown]
# 5. Run script to begin training and evaluate model. The model below is SASRec-SA2C.

# %%
# !python "/content/recommenders_aipi590/DRL_Recommenders/Dataset_1_Retail_Rocket/src/SA2C_v2.py" --model=SASRec --epoch=10 --data="/content/recommenders_aipi590/DRL_Recommenders/Dataset_1_Retail_Rocket/RR_data/"
# Out:
# 2022-12-13 14:57:54.899515: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# epoch 1
# the loss in 200th batch is: 10.830150
# the loss in 400th batch is: 10.822147
# the loss in 600th batch is: 10.499000
# the loss in 800th batch is: 10.427211
# the loss in 1000th batch is: 10.243729
# the loss in 1200th batch is: 9.892332
# the loss in 1400th batch is: 10.039438
# the loss in 1600th batch is: 10.212570
# the loss in 1800th batch is: 9.667624
# the loss in 2000th batch is: 9.742554
# the loss in 2200th batch is: 9.703595
# the loss in 2400th batch is: 9.487718
# the loss in 2600th batch is: 9.615972
# the loss in 2800th batch is: 9.071950
# the loss in 3000th batch is: 9.328615
# the loss in 3200th batch is: 9.071482
# the loss in 3400th batch is: 9.073617
# the loss in 3600th batch is: 8.758050
# the loss in 3800th batch is: 8.860233
# epoch 2
# the loss in 4000th batch is: 8.480970
# the loss in 4200th batch is: 8.476576
# the loss in 4400th batch is: 8.182581
# the loss in 4600th batch is: 8.572930
# the loss in 4800th batch is: 8.369334
# the loss in 5000th batch is: 8.008265
# the loss in 5200th batch is: 7.930021
# the loss in 5400th batch is: 7.743340
# the loss in 5600th batch is: 7.783518
# the loss in 5800th batch is: 7.380692
# the loss in 6000th batch is: 7.585617
# the loss in 6200th batch is: 8.151355
# the loss in 6400th batch is: 7.367826
# the loss in 6600th batch is: 8.030132
# the loss in 6800th batch is: 7.338546
# the loss in 7000th batch is: 7.121048
# the loss in 7200th batch is: 7.612628
# the loss in 7400th batch is: 7.727991
# the loss in 7600th batch is: 7.541550
# epoch 3
# the loss in 7800th batch is: 7.693051
# the loss in 8000th batch is: 7.371157
#
# Beginning evaluation...
# tcmalloc: large alloc 1500930048 bytes == 0xc0c28000 @  0x7fb53af831e7 0x7fb5057eb14e 0x7fb505843745 0x7fb505843878 0x7fb505889597 0x7fb50588d7dc 0x7fb5058dca72 0x5aae14 0x5d8416 0x5630f5 0x55cd91 0x5d8941 0x49abe4 0x55cd91 0x5d8941 0x5d8506 0x7fb50582d944 0x5d814d 0x5d8d8c 0x55dc1e 0x55cd91 0x5d8941 0x4997c7 0x55cd91 0x5d8941 0x4990ca 0x55cd91 0x55d743 0x642630 0x6426ae 0x644b78
# #############################################################
# total clicks: 117015, total purchase:5578
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 5: 8479.000000
# clicks hr ndcg @ 5 : 0.242448, 0.189976
# purchase hr and ndcg @5 : 0.502868, 0.430703
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 10: 9781.000000
# clicks hr ndcg @ 10 : 0.287698, 0.204625
# purchase hr and ndcg @10 : 0.546432, 0.444870
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 15: 10507.200000
# clicks hr ndcg @ 15 : 0.312661, 0.211243
# purchase hr and ndcg @15 : 0.571890, 0.451611
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 20: 10969.600000
# clicks hr ndcg @ 20 : 0.328445, 0.214974
# purchase hr and ndcg @20 : 0.588562, 0.455556
# off-line corrected evaluation (click_ng,purchase_ng)@10: 0.059911, 0.165961
# #############################################################
# the loss in 8200th batch is: 7.629318
# the loss in 8400th batch is: 7.136734
# the loss in 8600th batch is: 7.273467
# the loss in 8800th batch is: 7.250751
# the loss in 9000th batch is: 7.515810
# the loss in 9200th batch is: 6.830098
# the loss in 9400th batch is: 7.139941
# the loss in 9600th batch is: 7.097499
# the loss in 9800th batch is: 7.266991
# the loss in 10000th batch is: 6.626231
# the loss in 10200th batch is: 6.371046
# the loss in 10400th batch is: 6.574392
# the loss in 10600th batch is: 6.901660
# the loss in 10800th batch is: 6.225740
# the loss in 11000th batch is: 6.690725
# the loss in 11200th batch is: 6.425710
# the loss in 11400th batch is: 6.758057
# epoch 4
# the loss in 11600th batch is: 6.375115
# the loss in 11800th batch is: 6.828903
# the loss in 12000th batch is: 6.484047
# the loss in 12200th batch is: 6.335510
# the loss in 12400th batch is: 6.657133
# the loss in 12600th batch is: 6.629757
# the loss in 12800th batch is: 6.289610
# the loss in 13000th batch is: 6.368044
# the loss in 13200th batch is: 6.422411
# the loss in 13400th batch is: 6.481734
# the loss in 13600th batch is: 6.024317
# the loss in 13800th batch is: 6.157371
# the loss in 14000th batch is: 6.316780
# the loss in 14200th batch is: 5.913665
# the loss in 14400th batch is: 6.129069
# the loss in 14600th batch is: 6.356756
# the loss in 14800th batch is: 6.497295
# the loss in 15000th batch is: 6.601647
# the loss in 15200th batch is: 1.111005
# epoch 5
# the loss in 15400th batch is: 1.265761
# the loss in 15600th batch is: 1.205344
# the loss in 15800th batch is: 1.147457
# the loss in 16000th batch is: 1.035723
#
# Beginning evaluation...
# tcmalloc: large alloc 1500930048 bytes == 0xc0c28000 @  0x7fb53af831e7 0x7fb5057eb14e 0x7fb505843745 0x7fb505843878 0x7fb505889597 0x7fb50588d7dc 0x7fb5058dca72 0x5aae14 0x5d8416 0x5630f5 0x55cd91 0x5d8941 0x49abe4 0x55cd91 0x5d8941 0x5d8506 0x7fb50582d944 0x5d814d 0x5d8d8c 0x55dc1e 0x55cd91 0x5d8941 0x4997c7 0x55cd91 0x5d8941 0x4990ca 0x55cd91 0x55d743 0x642630 0x6426ae 0x644b78
# #############################################################
# total clicks: 117015, total purchase:5578
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 5: 8771.400000
# clicks hr ndcg @ 5 : 0.251609, 0.195955
# purchase hr and ndcg @5 : 0.516852, 0.434284
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 10: 10225.200000
# clicks hr ndcg @ 10 : 0.301038, 0.211970
# purchase hr and ndcg @10 : 0.570097, 0.451674
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 15: 11023.200000
# clicks hr ndcg @ 15 : 0.328343, 0.219203
# purchase hr and ndcg @15 : 0.598602, 0.459268
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 20: 11555.400000
# clicks hr ndcg @ 20 : 0.347195, 0.223660
# purchase hr and ndcg @20 : 0.614916, 0.463126
# off-line corrected evaluation (click_ng,purchase_ng)@10: 0.063000, 0.178929
# #############################################################
# the loss in 16200th batch is: 1.093636
# the loss in 16400th batch is: 1.000042
# the loss in 16600th batch is: 1.111328
# the loss in 16800th batch is: 1.069701
# the loss in 17000th batch is: 0.968391
# the loss in 17200th batch is: 1.043864
# the loss in 17400th batch is: 1.029091
# the loss in 17600th batch is: 1.021694
# the loss in 17800th batch is: 1.040623
# the loss in 18000th batch is: 1.006074
# the loss in 18200th batch is: 0.972401
# the loss in 18400th batch is: 0.987112
# the loss in 18600th batch is: 0.966641
# the loss in 18800th batch is: 1.029982
# the loss in 19000th batch is: 0.904187
# the loss in 19200th batch is: 0.988987
# epoch 6
# the loss in 19400th batch is: 1.051769
# the loss in 19600th batch is: 0.966098
# the loss in 19800th batch is: 0.935237
# the loss in 20000th batch is: 0.947952
# the loss in 20200th batch is: 0.924745
# the loss in 20400th batch is: 0.814779
# the loss in 20600th batch is: 0.911474
# the loss in 20800th batch is: 0.912664
# the loss in 21000th batch is: 0.910583
# the loss in 21200th batch is: 0.958983
# the loss in 21400th batch is: 0.833796
# the loss in 21600th batch is: 0.924467
# the loss in 21800th batch is: 0.772652
# the loss in 22000th batch is: 0.910976
# the loss in 22200th batch is: 0.795365
# the loss in 22400th batch is: 0.784948
# the loss in 22600th batch is: 0.851096
# the loss in 22800th batch is: 0.829745
# the loss in 23000th batch is: 0.798851
# epoch 7
# the loss in 23200th batch is: 0.863667
# the loss in 23400th batch is: 0.793330
# the loss in 23600th batch is: 0.798961
# the loss in 23800th batch is: 0.852445
# the loss in 24000th batch is: 0.734905
#
# Beginning evaluation...
# tcmalloc: large alloc 1500930048 bytes == 0xc0c28000 @  0x7fb53af831e7 0x7fb5057eb14e 0x7fb505843745 0x7fb505843878 0x7fb505889597 0x7fb50588d7dc 0x7fb5058dca72 0x5aae14 0x5d8416 0x5630f5 0x55cd91 0x5d8941 0x49abe4 0x55cd91 0x5d8941 0x5d8506 0x7fb50582d944 0x5d814d 0x5d8d8c 0x55dc1e 0x55cd91 0x5d8941 0x4997c7 0x55cd91 0x5d8941 0x4990ca 0x55cd91 0x55d743 0x642630 0x6426ae 0x644b78
# #############################################################
# total clicks: 117015, total purchase:5578
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 5: 9524.400000
# clicks hr ndcg @ 5 : 0.271991, 0.214159
# purchase hr and ndcg @5 : 0.566332, 0.491872
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 10: 10944.800000
# clicks hr ndcg @ 10 : 0.321702, 0.230303
# purchase hr and ndcg @10 : 0.612406, 0.506775
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 15: 11723.600000
# clicks hr ndcg @ 15 : 0.349682, 0.237719
# purchase hr and ndcg @15 : 0.634636, 0.512652
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 20: 12214.400000
# clicks hr ndcg @ 20 : 0.367662, 0.241968
# purchase hr and ndcg @20 : 0.647185, 0.515616
# off-line corrected evaluation (click_ng,purchase_ng)@10: 0.071703, 0.213339
# #############################################################
# the loss in 24200th batch is: 0.864645
# the loss in 24400th batch is: 0.842940
# the loss in 24600th batch is: 0.863160
# the loss in 24800th batch is: 0.823691
# the loss in 25000th batch is: 0.884774
# the loss in 25200th batch is: 0.847606
# the loss in 25400th batch is: 0.855794
# the loss in 25600th batch is: 0.771820
# the loss in 25800th batch is: 0.760339
# the loss in 26000th batch is: 0.737470
# the loss in 26200th batch is: 0.757407
# the loss in 26400th batch is: 0.760403
# the loss in 26600th batch is: 0.713670
# the loss in 26800th batch is: 0.712792
# epoch 8
# the loss in 27000th batch is: 0.708014
# the loss in 27200th batch is: 0.731695
# the loss in 27400th batch is: 0.688289
# the loss in 27600th batch is: 0.692062
# the loss in 27800th batch is: 0.756157
# the loss in 28000th batch is: 0.858794
# the loss in 28200th batch is: 0.825238
# the loss in 28400th batch is: 0.705539
# the loss in 28600th batch is: 0.801854
# the loss in 28800th batch is: 0.688404
# the loss in 29000th batch is: 0.636721
# the loss in 29200th batch is: 0.725217
# the loss in 29400th batch is: 0.707641
# the loss in 29600th batch is: 0.662509
# the loss in 29800th batch is: 0.676729
# the loss in 30000th batch is: 0.649194
# the loss in 30200th batch is: 0.787568
# the loss in 30400th batch is: 0.729304
# the loss in 30600th batch is: 0.751679
# epoch 9
# the loss in 30800th batch is: 0.750340
# the loss in 31000th batch is: 0.668258
# the loss in 31200th batch is: 0.747185
# the loss in 31400th batch is: 0.668320
# the loss in 31600th batch is: 0.673751
# the loss in 31800th batch is: 0.665467
# the loss in 32000th batch is: 0.735741
#
# Beginning evaluation...
# #############################################################
# total clicks: 117015, total purchase:5578
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 5: 9880.800000
# clicks hr ndcg @ 5 : 0.283118, 0.223137
# purchase hr and ndcg @5 : 0.583542, 0.508703
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 10: 11349.200000
# clicks hr ndcg @ 10 : 0.334282, 0.239741
# purchase hr and ndcg @10 : 0.632126, 0.524567
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 15: 12149.200000
# clicks hr ndcg @ 15 : 0.363381, 0.247464
# purchase hr and ndcg @15 : 0.653460, 0.530222
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 20: 12658.400000
# clicks hr ndcg @ 20 : 0.381720, 0.251799
# purchase hr and ndcg @20 : 0.667802, 0.533623
# off-line corrected evaluation (click_ng,purchase_ng)@10: 0.082232, 0.238408
# #############################################################
# the loss in 32200th batch is: 0.583789
# the loss in 32400th batch is: 0.739130
# the loss in 32600th batch is: 0.672276
# the loss in 32800th batch is: 0.615740
# the loss in 33000th batch is: 0.721575
# the loss in 33200th batch is: 0.692267
# the loss in 33400th batch is: 0.610413
# the loss in 33600th batch is: 0.703216
# the loss in 33800th batch is: 0.604095
# the loss in 34000th batch is: 0.666112
# the loss in 34200th batch is: 0.581970
# the loss in 34400th batch is: 0.666976
# the loss in 34600th batch is: 0.662671
# epoch 10
# the loss in 34800th batch is: 0.596954
# the loss in 35000th batch is: 0.629805
# the loss in 35200th batch is: 0.733502
# the loss in 35400th batch is: 0.615429
# the loss in 35600th batch is: 0.695419
# the loss in 35800th batch is: 0.693397
# the loss in 36000th batch is: 0.573320
# the loss in 36200th batch is: 0.634046
# the loss in 36400th batch is: 0.616498
# the loss in 36600th batch is: 0.634497
# the loss in 36800th batch is: 0.698148
# the loss in 37000th batch is: 0.634821
# the loss in 37200th batch is: 0.633312
# the loss in 37400th batch is: 0.601720
# the loss in 37600th batch is: 0.619971
# the loss in 37800th batch is: 0.625069
# the loss in 38000th batch is: 0.596955
# the loss in 38200th batch is: 0.642228
# the loss in 38400th batch is: 0.605208
# Training completed...
# Evaluating test dataset...
#
# #############################################################
# total clicks: 120730, total purchase:6190
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 5: 10484.200000
# clicks hr ndcg @ 5 : 0.284445, 0.223368
# purchase hr and ndcg @5 : 0.584168, 0.504708
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 10: 11957.000000
# clicks hr ndcg @ 10 : 0.334962, 0.239725
# purchase hr and ndcg @10 : 0.625040, 0.518020
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 15: 12719.200000
# clicks hr ndcg @ 15 : 0.361807, 0.246832
# purchase hr and ndcg @15 : 0.643457, 0.522910
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 20: 13266.800000
# clicks hr ndcg @ 20 : 0.380800, 0.251321
# purchase hr and ndcg @20 : 0.657835, 0.526312
# off-line corrected evaluation (click_ng,purchase_ng)@10: 0.085343, 0.232951
# #############################################################
